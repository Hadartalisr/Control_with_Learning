# %%
import os
import numpy as np
import gym
from gym import spaces
from math import sqrt
import torch
import torch.nn as nn
import torch.optim as optim

# Constants
SPACE_WIDTH = 100  # Half-width of the space [-SPACE_WIDTH, SPACE_WIDTH]
RESET_SPACE_WIDTH = SPACE_WIDTH - 2

# Define the Cube Environment
class CubeEnv(gym.Env):
    def __init__(self):
        super(CubeEnv, self).__init__()
        
        self.times_in_origin = 0
        
        # Define the state and action space
        self.state_space = spaces.Box(low=-SPACE_WIDTH, high=SPACE_WIDTH, shape=(3,), dtype=np.int32)
        self.action_space = spaces.Discrete(5)  # Four possible moves plus 'stay'
        
        # Initialize state
        self.state = np.array([np.random.randint(-SPACE_WIDTH, SPACE_WIDTH + 1), 
                               np.random.randint(-SPACE_WIDTH, SPACE_WIDTH + 1), 
                               0])
        
    def step(self, action):
        # Apply action to the state
        if action == 0:  
            self.state[0] += 1
        elif action == 1:  
            self.state[0] -= 1
        elif action == 2:  
            self.state[1] += 1
        elif action == 3:  
            self.state[1] -= 1
        # Action 4 is 'stay', do nothing
        
        # Clip the state to be within the state space
        self.state = np.clip(self.state, -SPACE_WIDTH, SPACE_WIDTH-1)
        
        # Calculate reward
        distance = 100 * self.state[0]**2 + self.state[1]**2  # + self.state[2]**2
        reward = -distance
        
        # Check if done
        done = self.is_done(self.state)
        
        return self.state, reward, done, {}

    def reset(self):
        # Reset the state to a random location on the Z=0 surface
        self.state = np.array([np.random.randint(-RESET_SPACE_WIDTH, RESET_SPACE_WIDTH + 1), 
                               np.random.randint(-RESET_SPACE_WIDTH, RESET_SPACE_WIDTH + 1), 
                               0])
        self.times_in_origin = 0
        return self.state

    def render(self, mode='human'):
        pass
    
    def is_done(self, state):
        in_origin = np.array_equal(state, np.array([0, 0, 0]))
        if in_origin: 
            self.times_in_origin += 1
            return self.times_in_origin > 20
        else:
            self.times_in_origin = 0
            return False


class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 10)
        self.fc2 = nn.Linear(10, 10)
        self.fc3 = nn.Linear(10, output_dim)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return x

# Define the Deep Q-Learning Agent
class DeepQLearningAgent:
    def __init__(self, env, initial_alpha=0.15, gamma=0.7, initial_epsilon=0.6, 
                 min_alpha=0.1, min_epsilon=0.15, alpha_decay=0.999, epsilon_decay=0.999):
        self.env = env
        self.alpha = initial_alpha
        self.gamma = gamma
        self.epsilon = initial_epsilon
        self.min_alpha = min_alpha
        self.min_epsilon = min_epsilon
        self.alpha_decay = alpha_decay
        self.epsilon_decay = epsilon_decay
        
        # Initialize Q-Network
        self.q_network = QNetwork(3, 5)  # State space: 3 dimensions, Action space: 5 actions
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=self.alpha)
        self.criterion = nn.MSELoss()

    def choose_action(self, state):
        if np.random.uniform(0, 1) < self.epsilon:
            return self.env.action_space.sample()
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                q_values = self.q_network(state_tensor)
            q_values = q_values.numpy().flatten()  # Convert to numpy array and flatten it
            max_q_value = np.max(q_values)  # Find the maximum Q-value
            max_actions = np.where(q_values == max_q_value)[0]  # Get indices of actions with max Q-value
            return np.random.choice(max_actions)  # Randomly select one of these actions
        
        
    def learn(self, state, action, reward, next_state):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
        action_tensor = torch.tensor([action])
        reward_tensor = torch.tensor([reward])
        
        current_q = self.q_network(state_tensor).gather(1, action_tensor.unsqueeze(0)).squeeze(0)
        next_q = self.q_network(next_state_tensor).max(1)[0]
        target_q = reward_tensor + self.gamma * next_q
        
        loss = self.criterion(current_q, target_q.detach())
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def decay_parameters(self):
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)
        self.alpha = max(self.min_alpha, self.alpha * self.alpha_decay)
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = self.alpha


def save_model(agent, filename):
    torch.save(agent.q_network.state_dict(), filename)
    print(f"Model saved to {filename}")


def load_model(agent, filename):
    agent.q_network.load_state_dict(torch.load(filename))
    agent.q_network.eval()  # Set the network to evaluation mode
    print(f"Model loaded from {filename}")


def print_weights(agent):
    state_dict = agent.q_network.state_dict()
    for key, value in state_dict.items():
        print(f"{key}: {value}")


# Training the agent
MAX_ITEREATIONS_PER_EPISODE = 2500
MODEL_FILE_NAME = "origins_models/q_network"

should_save_model = True
should_load_model = False

env = CubeEnv()
agent = DeepQLearningAgent(env, min_epsilon=0.01, initial_epsilon=0.8)

if should_load_model:
    load_model(agent, MODEL_FILE_NAME)

for episode in range(30001):
    state = env.reset()
    for iteration in range(MAX_ITEREATIONS_PER_EPISODE):
        action = agent.choose_action(state)
        next_state, reward, done, _ = env.step(action)
        agent.learn(state, action, reward, next_state)
        state = next_state
        if done:
            break
    
    agent.decay_parameters()
    
    if should_save_model and episode % 100 == 0:
        save_model(agent, MODEL_FILE_NAME + f"-{episode}.pth")
    
    print(f"Episode {episode + 1} finished")

print("Training completed")
# Out:
# Model saved to origins_models/q_network-0.pth
# Episode 1 finished
# Episode 2 finished
# Episode 3 finished
# Episode 4 finished
# Episode 5 finished
# Episode 6 finished
# Episode 7 finished
# Episode 8 finished
# Episode 9 finished
# Episode 10 finished
# Episode 11 finished
# Episode 12 finished
# Episode 13 finished
# Episode 14 finished
# Episode 15 finished
# Episode 16 finished
# Episode 17 finished
# Episode 18 finished
# Episode 19 finished
# Episode 20 finished
# Episode 21 finished
# Episode 22 finished
# Episode 23 finished
# Episode 24 finished
# Episode 25 finished
# Episode 26 finished
# Episode 27 finished
# Episode 28 finished
# Episode 29 finished
# Episode 30 finished
# Episode 31 finished
# Episode 32 finished
# Episode 33 finished
# Episode 34 finished
# Episode 35 finished
# Episode 36 finished
# Episode 37 finished
# Episode 38 finished
# Episode 39 finished
# Episode 40 finished
# Episode 41 finished
# Episode 42 finished
# Episode 43 finished
# Episode 44 finished
# Episode 45 finished
# Episode 46 finished
# Episode 47 finished
# Episode 48 finished
# Episode 49 finished
# Episode 50 finished
# Episode 51 finished
# Episode 52 finished
# Episode 53 finished
# Episode 54 finished
# Episode 55 finished
# Episode 56 finished
# Episode 57 finished
# Episode 58 finished
# Episode 59 finished
# Episode 60 finished
# Episode 61 finished
# Episode 62 finished
# Episode 63 finished
# Episode 64 finished
# Episode 65 finished
# Episode 66 finished
# Episode 67 finished
# Episode 68 finished
# Episode 69 finished
# Episode 70 finished
# Episode 71 finished
# Episode 72 finished
# Episode 73 finished
# Episode 74 finished
# Episode 75 finished
# Episode 76 finished
# Episode 77 finished
# Episode 78 finished
# Episode 79 finished
# Episode 80 finished
# Episode 81 finished
# Episode 82 finished
# Episode 83 finished
# Episode 84 finished
# Episode 85 finished
# Episode 86 finished
# Episode 87 finished
# Episode 88 finished
# Episode 89 finished
# Episode 90 finished
# Episode 91 finished
# Episode 92 finished
# Episode 93 finished
# Episode 94 finished
# Episode 95 finished
# Episode 96 finished
# Episode 97 finished
# Episode 98 finished
# Episode 99 finished
# Episode 100 finished
# Model saved to origins_models/q_network-100.pth
# Episode 101 finished
# Episode 102 finished
# Episode 103 finished
# Episode 104 finished
# Episode 105 finished
# Episode 106 finished
# Episode 107 finished
# Episode 108 finished
# Episode 109 finished
# Episode 110 finished
# Episode 111 finished
# Episode 112 finished
# Episode 113 finished
# Episode 114 finished
# Episode 115 finished
# Episode 116 finished
# Episode 117 finished
# Episode 118 finished
# Episode 119 finished
# Episode 120 finished
# Episode 121 finished
# Episode 122 finished
# Episode 123 finished
# Episode 124 finished
# Episode 125 finished
# Episode 126 finished
# Episode 127 finished
# Episode 128 finished
# Episode 129 finished
# Episode 130 finished
# Episode 131 finished
# Episode 132 finished
# Episode 133 finished
# Episode 134 finished
# Episode 135 finished
# Episode 136 finished
# Episode 137 finished
# Episode 138 finished
# Episode 139 finished
# Episode 140 finished
# Episode 141 finished
# Episode 142 finished
# Episode 143 finished
# Episode 144 finished
# Episode 145 finished
# Episode 146 finished
# Episode 147 finished
# Episode 148 finished
# Episode 149 finished
# Episode 150 finished
# Episode 151 finished
# Episode 152 finished
# Episode 153 finished
# Episode 154 finished
# Episode 155 finished
# Episode 156 finished
# Episode 157 finished
# Episode 158 finished
# Episode 159 finished
# Episode 160 finished
# Episode 161 finished
# Episode 162 finished
# Episode 163 finished
# Episode 164 finished
# Episode 165 finished
# Episode 166 finished
# Episode 167 finished
# Episode 168 finished
# Episode 169 finished
# Episode 170 finished
# Episode 171 finished
# Episode 172 finished
# Episode 173 finished
# Episode 174 finished
# Episode 175 finished
# Episode 176 finished
# Episode 177 finished
# Episode 178 finished
# Episode 179 finished
# Episode 180 finished
# Episode 181 finished
# Episode 182 finished
# Episode 183 finished
# Episode 184 finished
# Episode 185 finished
# Episode 186 finished
# Episode 187 finished
# Episode 188 finished
# Episode 189 finished
# Episode 190 finished
# Episode 191 finished
# Episode 192 finished
# Episode 193 finished
# Episode 194 finished
# Episode 195 finished
# Episode 196 finished
# Episode 197 finished
# Episode 198 finished
# Episode 199 finished
# Episode 200 finished
# Model saved to origins_models/q_network-200.pth
# Episode 201 finished
# Episode 202 finished
# Episode 203 finished
# Episode 204 finished
# Episode 205 finished
# Episode 206 finished
# Episode 207 finished
# Episode 208 finished
# Episode 209 finished
# Episode 210 finished
# Episode 211 finished
# Episode 212 finished
# Episode 213 finished
# Episode 214 finished
# Episode 215 finished
# Episode 216 finished
# Episode 217 finished
# Episode 218 finished
# Episode 219 finished
# Episode 220 finished
# Episode 221 finished
# Episode 222 finished
# Episode 223 finished
# Episode 224 finished
# Episode 225 finished
# Episode 226 finished
# Episode 227 finished
# Episode 228 finished
# Episode 229 finished
# Episode 230 finished
# Episode 231 finished
# Episode 232 finished
# Episode 233 finished
# Episode 234 finished
# Episode 235 finished
# Episode 236 finished
# Episode 237 finished
# Episode 238 finished
# Episode 239 finished
# Episode 240 finished
# Episode 241 finished
# Episode 242 finished
# Episode 243 finished
# Episode 244 finished
# Episode 245 finished
# Episode 246 finished
# Episode 247 finished
# Episode 248 finished
# Episode 249 finished
# Episode 250 finished
# Episode 251 finished
# Episode 252 finished
# Episode 253 finished
# Episode 254 finished
# Episode 255 finished
# Episode 256 finished
# Episode 257 finished
# Episode 258 finished
# Episode 259 finished
# Episode 260 finished
# Episode 261 finished
# Episode 262 finished
# Episode 263 finished
# Episode 264 finished
# Episode 265 finished
# Episode 266 finished
# Episode 267 finished
# Episode 268 finished
# Episode 269 finished
# Episode 270 finished
# Episode 271 finished
# Episode 272 finished
# Episode 273 finished
# Episode 274 finished
# Episode 275 finished
# Episode 276 finished
# Episode 277 finished
# Episode 278 finished
# Episode 279 finished
# Episode 280 finished
# Episode 281 finished
# Episode 282 finished
# Episode 283 finished
# Episode 284 finished
# Episode 285 finished
# Episode 286 finished
# Episode 287 finished
# Episode 288 finished
# Episode 289 finished
# Episode 290 finished
# Episode 291 finished
# Episode 292 finished
# Episode 293 finished
# Episode 294 finished
# Episode 295 finished
# Episode 296 finished
# Episode 297 finished
# Episode 298 finished
# Episode 299 finished
# Episode 300 finished
# Model saved to origins_models/q_network-300.pth
# Episode 301 finished
# Episode 302 finished
# Episode 303 finished
# Episode 304 finished
# Episode 305 finished
# Episode 306 finished
# Episode 307 finished
# Episode 308 finished
# Episode 309 finished
# Episode 310 finished
# Episode 311 finished
# Episode 312 finished
# Episode 313 finished
# Episode 314 finished
# Episode 315 finished
# Episode 316 finished
# Episode 317 finished
# Episode 318 finished
# Episode 319 finished
# Episode 320 finished
# Episode 321 finished
# Episode 322 finished
# Episode 323 finished
# Episode 324 finished
# Episode 325 finished
# Episode 326 finished
# Episode 327 finished
# Episode 328 finished
# Episode 329 finished
# Episode 330 finished
# Episode 331 finished
# Episode 332 finished
# Episode 333 finished
# Episode 334 finished
# Episode 335 finished
# Episode 336 finished
# Episode 337 finished
# Episode 338 finished
# Episode 339 finished
# Episode 340 finished
# Episode 341 finished
# Episode 342 finished
# Episode 343 finished
# Episode 344 finished
# Episode 345 finished
# Episode 346 finished
# Episode 347 finished
# Episode 348 finished
# Episode 349 finished
# Episode 350 finished
# Episode 351 finished
# Episode 352 finished
# Episode 353 finished
# Episode 354 finished
# Episode 355 finished
# Episode 356 finished
# Episode 357 finished
# Episode 358 finished
# Episode 359 finished
# Episode 360 finished
# Episode 361 finished
# Episode 362 finished
# Episode 363 finished
# Episode 364 finished
# Episode 365 finished
# Episode 366 finished
# Episode 367 finished
# Episode 368 finished
# Episode 369 finished
# Episode 370 finished
# Episode 371 finished
# Episode 372 finished
# Episode 373 finished
# Episode 374 finished
# Episode 375 finished
# Episode 376 finished
# Episode 377 finished
# Episode 378 finished
# Episode 379 finished
# Episode 380 finished
# Episode 381 finished
# Episode 382 finished
# Episode 383 finished
# Episode 384 finished
# Episode 385 finished
# Episode 386 finished
# Episode 387 finished
# Episode 388 finished
# Episode 389 finished
# Episode 390 finished
# Episode 391 finished
# Episode 392 finished
# Episode 393 finished
# Episode 394 finished
# Episode 395 finished
# Episode 396 finished
# Episode 397 finished
# Episode 398 finished
# Episode 399 finished
# Episode 400 finished
# Model saved to origins_models/q_network-400.pth
# Episode 401 finished
# Episode 402 finished
# Episode 403 finished
# Episode 404 finished
# Episode 405 finished
# Episode 406 finished
# Episode 407 finished
# Episode 408 finished
# Episode 409 finished
# Episode 410 finished
# Episode 411 finished
# Episode 412 finished
# Episode 413 finished
# Episode 414 finished
# Episode 415 finished
# Episode 416 finished
# Episode 417 finished
# Episode 418 finished
# Episode 419 finished
# Episode 420 finished
# Episode 421 finished
# Episode 422 finished
# Episode 423 finished
# Episode 424 finished
# Episode 425 finished
# Episode 426 finished
# Episode 427 finished
# Episode 428 finished
# Episode 429 finished
# Episode 430 finished
# Episode 431 finished
# Episode 432 finished
# Episode 433 finished
# Episode 434 finished
# Episode 435 finished
# Episode 436 finished
# Episode 437 finished
# Episode 438 finished
# Episode 439 finished
# Episode 440 finished
# Episode 441 finished
# Episode 442 finished
# Episode 443 finished
# Episode 444 finished
# Episode 445 finished
# Episode 446 finished
# Episode 447 finished
# Episode 448 finished
# Episode 449 finished
# Episode 450 finished
# Episode 451 finished
# Episode 452 finished
# Episode 453 finished
# Episode 454 finished
# Episode 455 finished
# Episode 456 finished
# Episode 457 finished
# Episode 458 finished
# Episode 459 finished
# Episode 460 finished
# Episode 461 finished
# Episode 462 finished
# Episode 463 finished
# Episode 464 finished
# Episode 465 finished
# Episode 466 finished
# Episode 467 finished
# Episode 468 finished
# Episode 469 finished
# Episode 470 finished
# Episode 471 finished
# Episode 472 finished
# Episode 473 finished
# Episode 474 finished
# Episode 475 finished
# Episode 476 finished
# Episode 477 finished
# Episode 478 finished
# Episode 479 finished
# Episode 480 finished
# Episode 481 finished
# Episode 482 finished
# Episode 483 finished
# Episode 484 finished
# Episode 485 finished
# Episode 486 finished
# Episode 487 finished
# Episode 488 finished
# Episode 489 finished
# Episode 490 finished
# Episode 491 finished
# Episode 492 finished
# Episode 493 finished
# Episode 494 finished
# Episode 495 finished
# Episode 496 finished
# Episode 497 finished
# Episode 498 finished
# Episode 499 finished
# Episode 500 finished
# Model saved to origins_models/q_network-500.pth
# Episode 501 finished
# Episode 502 finished
# Episode 503 finished
# Episode 504 finished
# Episode 505 finished
# Episode 506 finished
# Episode 507 finished
# Episode 508 finished
# Episode 509 finished
# Episode 510 finished
# Episode 511 finished
# Episode 512 finished
# Episode 513 finished
# Episode 514 finished
# Episode 515 finished
# Episode 516 finished
# Episode 517 finished
# Episode 518 finished
# Episode 519 finished
# Episode 520 finished
# Episode 521 finished
# Episode 522 finished
# Episode 523 finished
# Episode 524 finished
# Episode 525 finished
# Episode 526 finished
# Episode 527 finished
# Episode 528 finished
# Episode 529 finished
# Episode 530 finished
# Episode 531 finished
# Episode 532 finished
# Episode 533 finished
# Episode 534 finished
# Episode 535 finished
# Episode 536 finished
# Episode 537 finished
# Episode 538 finished
# Episode 539 finished
# Episode 540 finished
# Episode 541 finished
# Episode 542 finished
# Episode 543 finished
# Episode 544 finished
# Episode 545 finished
# Episode 546 finished
# Episode 547 finished
# Episode 548 finished
# Episode 549 finished
# Episode 550 finished
# Episode 551 finished
# Episode 552 finished
# Episode 553 finished
# Episode 554 finished
# Episode 555 finished
# Episode 556 finished
# Episode 557 finished
# Episode 558 finished
# Episode 559 finished
# Episode 560 finished
# Episode 561 finished
# Episode 562 finished
# Episode 563 finished
# Episode 564 finished
# Episode 565 finished
# Episode 566 finished
# Episode 567 finished
# Episode 568 finished
# Episode 569 finished
# Episode 570 finished
# Episode 571 finished
# Episode 572 finished
# Episode 573 finished
# Episode 574 finished
# Episode 575 finished
# Episode 576 finished
# Episode 577 finished
# Episode 578 finished
# Episode 579 finished
# Episode 580 finished
# Episode 581 finished
# Episode 582 finished
# Episode 583 finished
# Episode 584 finished
# Episode 585 finished
# Episode 586 finished
# Episode 587 finished
# Episode 588 finished
# Episode 589 finished
# Episode 590 finished
# Episode 591 finished
# Episode 592 finished
# Episode 593 finished
# Episode 594 finished
# Episode 595 finished
# Episode 596 finished
# Episode 597 finished
# Episode 598 finished
# Episode 599 finished
# Episode 600 finished
# Model saved to origins_models/q_network-600.pth
# Episode 601 finished
# Episode 602 finished
# Episode 603 finished
# Episode 604 finished
# Episode 605 finished
# Episode 606 finished
# Episode 607 finished
# Episode 608 finished
# Episode 609 finished
# Episode 610 finished
# Episode 611 finished
# Episode 612 finished
# Episode 613 finished
# Episode 614 finished
# Episode 615 finished
# Episode 616 finished
# Episode 617 finished
# Episode 618 finished
# Episode 619 finished
# Episode 620 finished
# Episode 621 finished
# Episode 622 finished
# Episode 623 finished
# Episode 624 finished
# Episode 625 finished
# Episode 626 finished
# Episode 627 finished
# Episode 628 finished
# Episode 629 finished
# Episode 630 finished
# Episode 631 finished
# Episode 632 finished
# Episode 633 finished
# Episode 634 finished
# Episode 635 finished
# Episode 636 finished
# Episode 637 finished
# Episode 638 finished
# Episode 639 finished
# Episode 640 finished
# Episode 641 finished
# Episode 642 finished
# Episode 643 finished
# Episode 644 finished
# Episode 645 finished
# Episode 646 finished
# Episode 647 finished
# Episode 648 finished
# Episode 649 finished
# Episode 650 finished
# Episode 651 finished
# Episode 652 finished
# Episode 653 finished
# Episode 654 finished
# Episode 655 finished
# Episode 656 finished
# Episode 657 finished
# Episode 658 finished
# Episode 659 finished
# Episode 660 finished
# Episode 661 finished
# Episode 662 finished
# Episode 663 finished
# Episode 664 finished
# Episode 665 finished
# Episode 666 finished
# Episode 667 finished
# Episode 668 finished
# Episode 669 finished
# Episode 670 finished
# Episode 671 finished
# Episode 672 finished
# Episode 673 finished
# Episode 674 finished
# Episode 675 finished
# Episode 676 finished
# Episode 677 finished
# Episode 678 finished
# Episode 679 finished
# Episode 680 finished
# Episode 681 finished
# Episode 682 finished
# Episode 683 finished
# Episode 684 finished
# Episode 685 finished
# Episode 686 finished
# Episode 687 finished
# Episode 688 finished
# Episode 689 finished
# Episode 690 finished
# Episode 691 finished
# Episode 692 finished
# Episode 693 finished
# Episode 694 finished
# Episode 695 finished
# Episode 696 finished
# Episode 697 finished
# Episode 698 finished
# Episode 699 finished
# Episode 700 finished
# Model saved to origins_models/q_network-700.pth
# Episode 701 finished
# Episode 702 finished
# Episode 703 finished
# Episode 704 finished
# Episode 705 finished
# Episode 706 finished
# Episode 707 finished
# Episode 708 finished
# Episode 709 finished
# Episode 710 finished
# Episode 711 finished
# Episode 712 finished
# Episode 713 finished
# Episode 714 finished
# Episode 715 finished
# Episode 716 finished
# Episode 717 finished
# Episode 718 finished
# Episode 719 finished
# Episode 720 finished
# Episode 721 finished
# Episode 722 finished
# Episode 723 finished
# Episode 724 finished
# Episode 725 finished
# Episode 726 finished
# Episode 727 finished
# Episode 728 finished
# Episode 729 finished
# Episode 730 finished
# Episode 731 finished
# Episode 732 finished
# Episode 733 finished
# Episode 734 finished
# Episode 735 finished
# Episode 736 finished
# Episode 737 finished
# Episode 738 finished
# Episode 739 finished
# Episode 740 finished
# Episode 741 finished
# Episode 742 finished
# Episode 743 finished
# Episode 744 finished
# Episode 745 finished
# Episode 746 finished
# Episode 747 finished
# Episode 748 finished
# Episode 749 finished
# Episode 750 finished
# Episode 751 finished
# Episode 752 finished
# Episode 753 finished
# Episode 754 finished
# Episode 755 finished
# Episode 756 finished
# Episode 757 finished
# Episode 758 finished
# Episode 759 finished
# Episode 760 finished
# Episode 761 finished
# Episode 762 finished
# Episode 763 finished
# Episode 764 finished
# Episode 765 finished
# Episode 766 finished
# Episode 767 finished
# Episode 768 finished
# Episode 769 finished
# Episode 770 finished
# Episode 771 finished
# Episode 772 finished
# Episode 773 finished
# Episode 774 finished
# Episode 775 finished
# Episode 776 finished
# Episode 777 finished
# Episode 778 finished
# Episode 779 finished
# Episode 780 finished
# Episode 781 finished
# Episode 782 finished
# Episode 783 finished
# Episode 784 finished
# Episode 785 finished
# Episode 786 finished
# Episode 787 finished
# Episode 788 finished
# Episode 789 finished
# Episode 790 finished
# Episode 791 finished
# Episode 792 finished
# Episode 793 finished
# Episode 794 finished
# Episode 795 finished
# Episode 796 finished
# Episode 797 finished
# Episode 798 finished
# Episode 799 finished
# Episode 800 finished
# Model saved to origins_models/q_network-800.pth
# Episode 801 finished
# Episode 802 finished
# Episode 803 finished
# Episode 804 finished
# Episode 805 finished
# Episode 806 finished
# Episode 807 finished
# Episode 808 finished
# Episode 809 finished
# Episode 810 finished
# Episode 811 finished
# Episode 812 finished
# Episode 813 finished
# Episode 814 finished
# Episode 815 finished
# Episode 816 finished
# Episode 817 finished
# Episode 818 finished
# Episode 819 finished
# Episode 820 finished
# Episode 821 finished
# Episode 822 finished
# Episode 823 finished
# Episode 824 finished
# Episode 825 finished
# Episode 826 finished
# Episode 827 finished
# Episode 828 finished
# Episode 829 finished
# Episode 830 finished
# Episode 831 finished
# Episode 832 finished
# Episode 833 finished
# Episode 834 finished
# Episode 835 finished
# Episode 836 finished
# Episode 837 finished
# Episode 838 finished
# Episode 839 finished
# Episode 840 finished
# Episode 841 finished
# Episode 842 finished
# Episode 843 finished
# Episode 844 finished
# Episode 845 finished
# Episode 846 finished
# Episode 847 finished
# Episode 848 finished
# Episode 849 finished
# Episode 850 finished
# Episode 851 finished
# Episode 852 finished
# Episode 853 finished
# Episode 854 finished
# Episode 855 finished
# Episode 856 finished
# Episode 857 finished
# Episode 858 finished
# Episode 859 finished
# Episode 860 finished
# Episode 861 finished
# Episode 862 finished
# Episode 863 finished
# Episode 864 finished
# Episode 865 finished
# Episode 866 finished
# Episode 867 finished
# Episode 868 finished
# Episode 869 finished
# Episode 870 finished
# Episode 871 finished
# Episode 872 finished
# Episode 873 finished
# Episode 874 finished
# Episode 875 finished
# Episode 876 finished
# Episode 877 finished
# Episode 878 finished
# Episode 879 finished
# Episode 880 finished
# Episode 881 finished
# Episode 882 finished
# Episode 883 finished
# Episode 884 finished
# Episode 885 finished
# Episode 886 finished
# Episode 887 finished
# Episode 888 finished
# Episode 889 finished
# Episode 890 finished
# Episode 891 finished
# Episode 892 finished
# Episode 893 finished
# Episode 894 finished
# Episode 895 finished
# Episode 896 finished
# Episode 897 finished
# Episode 898 finished
# Episode 899 finished
# Episode 900 finished
# Model saved to origins_models/q_network-900.pth
# Episode 901 finished
# Episode 902 finished
# Episode 903 finished
# Episode 904 finished
# Episode 905 finished
# Episode 906 finished
# Episode 907 finished
# Episode 908 finished
# Episode 909 finished
# Episode 910 finished
# Episode 911 finished
# Episode 912 finished
# Episode 913 finished
# Episode 914 finished
# Episode 915 finished
# Episode 916 finished
# Episode 917 finished
# Episode 918 finished
# Episode 919 finished
# Episode 920 finished
# Episode 921 finished
# Episode 922 finished
# Episode 923 finished
# Episode 924 finished
# Episode 925 finished
# Episode 926 finished
# Episode 927 finished
# Episode 928 finished
# Episode 929 finished
# Episode 930 finished
# Episode 931 finished
# Episode 932 finished
# Episode 933 finished
# Episode 934 finished
# Episode 935 finished
# Episode 936 finished
# Episode 937 finished
# Episode 938 finished
# Episode 939 finished
# Episode 940 finished
# Episode 941 finished
# Episode 942 finished
# Episode 943 finished
# Episode 944 finished
# Episode 945 finished
# Episode 946 finished
# Episode 947 finished
# Episode 948 finished
# Episode 949 finished
# Episode 950 finished
# Episode 951 finished
# Episode 952 finished
# Episode 953 finished
# Episode 954 finished
# Episode 955 finished
# Episode 956 finished
# Episode 957 finished
# Episode 958 finished
# Episode 959 finished
# Episode 960 finished
# Episode 961 finished
# Episode 962 finished
# Episode 963 finished
# Episode 964 finished
# Episode 965 finished
# Episode 966 finished
# Episode 967 finished
# Episode 968 finished
# Episode 969 finished
# Episode 970 finished
# Episode 971 finished
# Episode 972 finished
# Episode 973 finished
# Episode 974 finished
# Episode 975 finished
# Episode 976 finished
# Episode 977 finished
# Episode 978 finished
# Episode 979 finished
# Episode 980 finished
# Episode 981 finished
# Episode 982 finished
# Episode 983 finished
# Episode 984 finished
# Episode 985 finished
# Episode 986 finished
# Episode 987 finished
# Episode 988 finished
# Episode 989 finished
# Episode 990 finished
# Episode 991 finished
# Episode 992 finished
# Episode 993 finished
# Episode 994 finished
# Episode 995 finished
# Episode 996 finished
# Episode 997 finished
# Episode 998 finished
# Episode 999 finished
# Episode 1000 finished
# Model saved to origins_models/q_network-1000.pth
# Episode 1001 finished
# Episode 1002 finished
# Episode 1003 finished
# Episode 1004 finished
# Episode 1005 finished
# Episode 1006 finished
# Episode 1007 finished
# Episode 1008 finished
# Episode 1009 finished
# Episode 1010 finished
# Episode 1011 finished
# Episode 1012 finished
# Episode 1013 finished
# Episode 1014 finished
# Episode 1015 finished
# Episode 1016 finished
# Episode 1017 finished
# Episode 1018 finished
# Episode 1019 finished
# Episode 1020 finished
# Episode 1021 finished
# Episode 1022 finished
# Episode 1023 finished
# Episode 1024 finished
# Episode 1025 finished
# Episode 1026 finished
# Episode 1027 finished
# Episode 1028 finished
# Episode 1029 finished
# Episode 1030 finished
# Episode 1031 finished
# Episode 1032 finished
# Episode 1033 finished
# Episode 1034 finished
# Episode 1035 finished
# Episode 1036 finished
# Episode 1037 finished
# Episode 1038 finished
# Episode 1039 finished
# Episode 1040 finished
# Episode 1041 finished
# Episode 1042 finished
# Episode 1043 finished
# Episode 1044 finished
# Episode 1045 finished
# Episode 1046 finished
# Episode 1047 finished
# Episode 1048 finished
# Episode 1049 finished
# Episode 1050 finished
# Episode 1051 finished
# Episode 1052 finished
# Episode 1053 finished
# Episode 1054 finished
# Episode 1055 finished
# Episode 1056 finished
# Episode 1057 finished
# Episode 1058 finished
# Episode 1059 finished
# Episode 1060 finished
# Episode 1061 finished
# Episode 1062 finished
# Episode 1063 finished
# Episode 1064 finished
# Episode 1065 finished
# Episode 1066 finished
# Episode 1067 finished
# Episode 1068 finished
# Episode 1069 finished
# Episode 1070 finished
# Episode 1071 finished
# Episode 1072 finished
# Episode 1073 finished
# Episode 1074 finished
# Episode 1075 finished
# Episode 1076 finished
# Episode 1077 finished
# Episode 1078 finished
# Episode 1079 finished
# Episode 1080 finished
# Episode 1081 finished
# Episode 1082 finished
# Episode 1083 finished
# Episode 1084 finished
# Episode 1085 finished
# Episode 1086 finished
# Episode 1087 finished
# Episode 1088 finished
# Episode 1089 finished
# Episode 1090 finished
# Episode 1091 finished
# Episode 1092 finished
# Episode 1093 finished
# Episode 1094 finished
# Episode 1095 finished
# Episode 1096 finished
# Episode 1097 finished
# Episode 1098 finished
# Episode 1099 finished
# Episode 1100 finished
# Model saved to origins_models/q_network-1100.pth
# Episode 1101 finished
# Episode 1102 finished
# Episode 1103 finished
# Episode 1104 finished
# Episode 1105 finished
# Episode 1106 finished
# Episode 1107 finished
# Episode 1108 finished
# Episode 1109 finished
# Episode 1110 finished
# Episode 1111 finished
# Episode 1112 finished
# Episode 1113 finished
# Episode 1114 finished
# Episode 1115 finished
# Episode 1116 finished
# Episode 1117 finished
# Episode 1118 finished
# Episode 1119 finished
# Episode 1120 finished
# Episode 1121 finished
# Episode 1122 finished
# Episode 1123 finished
# Episode 1124 finished
# Episode 1125 finished
# Episode 1126 finished
# Episode 1127 finished
# Episode 1128 finished
# Episode 1129 finished
# Episode 1130 finished
# Episode 1131 finished
# Episode 1132 finished
# Episode 1133 finished
# Episode 1134 finished
# Episode 1135 finished
# Episode 1136 finished
# Episode 1137 finished
# Episode 1138 finished
# Episode 1139 finished
# Episode 1140 finished
# Episode 1141 finished
# Episode 1142 finished
# Episode 1143 finished
# Episode 1144 finished
# Episode 1145 finished
# Episode 1146 finished
# Episode 1147 finished
# Episode 1148 finished
# Episode 1149 finished
# Episode 1150 finished
# Episode 1151 finished
# Episode 1152 finished
# Episode 1153 finished
# Episode 1154 finished
# Episode 1155 finished
# Episode 1156 finished
# Episode 1157 finished
# Episode 1158 finished
# Episode 1159 finished
# Episode 1160 finished
# Episode 1161 finished
# Episode 1162 finished
# Episode 1163 finished
# Episode 1164 finished
# Episode 1165 finished
# Episode 1166 finished
# Episode 1167 finished
# Episode 1168 finished
# Episode 1169 finished
# Episode 1170 finished
# Episode 1171 finished
# Episode 1172 finished
# Episode 1173 finished
# Episode 1174 finished
# Episode 1175 finished
# Episode 1176 finished
# Episode 1177 finished
# Episode 1178 finished
# Episode 1179 finished
# Episode 1180 finished
# Episode 1181 finished
# Episode 1182 finished
# Episode 1183 finished
# Episode 1184 finished
# Episode 1185 finished
# Episode 1186 finished
# Episode 1187 finished
# Episode 1188 finished
# Episode 1189 finished
# Episode 1190 finished
# Episode 1191 finished
# Episode 1192 finished
# Episode 1193 finished
# Episode 1194 finished
# Episode 1195 finished
# Episode 1196 finished
# Episode 1197 finished
# Episode 1198 finished
# Episode 1199 finished
# Episode 1200 finished
# Model saved to origins_models/q_network-1200.pth
# Episode 1201 finished
# Episode 1202 finished
# Episode 1203 finished
# Episode 1204 finished
# Episode 1205 finished
# Episode 1206 finished
# Episode 1207 finished
# Episode 1208 finished
# Episode 1209 finished
# Episode 1210 finished
# Episode 1211 finished
# Episode 1212 finished
# Episode 1213 finished
# Episode 1214 finished
# Episode 1215 finished
# Episode 1216 finished
# Episode 1217 finished
# Episode 1218 finished
# Episode 1219 finished
# Episode 1220 finished
# Episode 1221 finished
# Episode 1222 finished
# Episode 1223 finished
# Episode 1224 finished
# Episode 1225 finished
# Episode 1226 finished
# Episode 1227 finished
# Episode 1228 finished
# Episode 1229 finished
# Episode 1230 finished
# Episode 1231 finished
# Episode 1232 finished
# Episode 1233 finished
# Episode 1234 finished
# Episode 1235 finished
# Episode 1236 finished
# Episode 1237 finished
# Episode 1238 finished
# Episode 1239 finished
# Episode 1240 finished
# Episode 1241 finished
# Episode 1242 finished
# Episode 1243 finished
# Episode 1244 finished
# Episode 1245 finished
# Episode 1246 finished
# Episode 1247 finished
# Episode 1248 finished
# Episode 1249 finished
# Episode 1250 finished
# Episode 1251 finished
# Episode 1252 finished
# Episode 1253 finished
# Episode 1254 finished
# Episode 1255 finished
# Episode 1256 finished
# Episode 1257 finished
# Episode 1258 finished
# Episode 1259 finished
# Episode 1260 finished
# Episode 1261 finished
# Episode 1262 finished
# Episode 1263 finished
# Episode 1264 finished
# Episode 1265 finished
# Episode 1266 finished
# Episode 1267 finished
# Episode 1268 finished
# Episode 1269 finished
# Episode 1270 finished
# Episode 1271 finished
# Episode 1272 finished
# Episode 1273 finished
# Episode 1274 finished
# Episode 1275 finished
# Episode 1276 finished
# Episode 1277 finished
# Episode 1278 finished
# Episode 1279 finished
# Episode 1280 finished
# Episode 1281 finished
# Episode 1282 finished
# Episode 1283 finished
# Episode 1284 finished
# Episode 1285 finished
# Episode 1286 finished
# Episode 1287 finished
# Episode 1288 finished
# Episode 1289 finished
# Episode 1290 finished
# Episode 1291 finished
# Episode 1292 finished
# Episode 1293 finished
# Episode 1294 finished
# Episode 1295 finished
# Episode 1296 finished
# Episode 1297 finished
# Episode 1298 finished
# Episode 1299 finished
# Episode 1300 finished
# Model saved to origins_models/q_network-1300.pth
# Episode 1301 finished
# Episode 1302 finished
# Episode 1303 finished
# Episode 1304 finished
# Episode 1305 finished
# Episode 1306 finished
# Episode 1307 finished
# Episode 1308 finished
# Episode 1309 finished
# Episode 1310 finished
# Episode 1311 finished
# Episode 1312 finished
# Episode 1313 finished
# Episode 1314 finished
# Episode 1315 finished
# Episode 1316 finished
# Episode 1317 finished
# Episode 1318 finished
# Episode 1319 finished
# Episode 1320 finished
# Episode 1321 finished
# Episode 1322 finished
# Episode 1323 finished
# Episode 1324 finished
# Episode 1325 finished
# Episode 1326 finished
# Episode 1327 finished
# Episode 1328 finished
# Episode 1329 finished
# Episode 1330 finished
# Episode 1331 finished
# Episode 1332 finished
# Episode 1333 finished
# Episode 1334 finished
# Episode 1335 finished
# Episode 1336 finished
# Episode 1337 finished
# Episode 1338 finished
# Episode 1339 finished
# Episode 1340 finished
# Episode 1341 finished
# Episode 1342 finished
# Episode 1343 finished
# Episode 1344 finished
# Episode 1345 finished
# Episode 1346 finished
# Episode 1347 finished
# Episode 1348 finished
# Episode 1349 finished
# Episode 1350 finished
# Episode 1351 finished
# Episode 1352 finished
# Episode 1353 finished
# Episode 1354 finished
# Episode 1355 finished
# Episode 1356 finished
# Episode 1357 finished
# Episode 1358 finished
# Episode 1359 finished
# Episode 1360 finished
# Episode 1361 finished
# Episode 1362 finished
# Episode 1363 finished
# Episode 1364 finished
# Episode 1365 finished
# Episode 1366 finished
# Episode 1367 finished
# Episode 1368 finished
# Episode 1369 finished
# Episode 1370 finished
# Episode 1371 finished
# Episode 1372 finished
# Episode 1373 finished
# Episode 1374 finished
# Episode 1375 finished
# Episode 1376 finished
# Episode 1377 finished
# Episode 1378 finished
# Episode 1379 finished
# Episode 1380 finished
# Episode 1381 finished
# Episode 1382 finished
# Episode 1383 finished
# Episode 1384 finished
# Episode 1385 finished
# Episode 1386 finished
# Episode 1387 finished
# Episode 1388 finished
# Episode 1389 finished
# Episode 1390 finished
# Episode 1391 finished
# Episode 1392 finished
# Episode 1393 finished
# Episode 1394 finished
# Episode 1395 finished
# Episode 1396 finished
# Episode 1397 finished
# Episode 1398 finished
# Episode 1399 finished
# Episode 1400 finished
# Model saved to origins_models/q_network-1400.pth
# Episode 1401 finished
# Episode 1402 finished
# Episode 1403 finished
# Episode 1404 finished
# Episode 1405 finished
# Episode 1406 finished
# Episode 1407 finished
# Episode 1408 finished
# Episode 1409 finished
# Episode 1410 finished
# Episode 1411 finished
# Episode 1412 finished
# Episode 1413 finished
# Episode 1414 finished
# Episode 1415 finished
# Episode 1416 finished
# Episode 1417 finished
# Episode 1418 finished
# Episode 1419 finished
# Episode 1420 finished
# Episode 1421 finished
# Episode 1422 finished
# Episode 1423 finished
# Episode 1424 finished
# Episode 1425 finished
# Episode 1426 finished
# Episode 1427 finished
# Episode 1428 finished
# Episode 1429 finished
# Episode 1430 finished
# Episode 1431 finished
# Episode 1432 finished
# Episode 1433 finished
# Episode 1434 finished
# Episode 1435 finished
# Episode 1436 finished
# Episode 1437 finished
# Episode 1438 finished
# Episode 1439 finished
# Episode 1440 finished
# Episode 1441 finished
# Episode 1442 finished
# Episode 1443 finished
# Episode 1444 finished
# Episode 1445 finished
# Episode 1446 finished
# Episode 1447 finished
# Episode 1448 finished
# Episode 1449 finished
# Episode 1450 finished
# Episode 1451 finished
# Episode 1452 finished
# Episode 1453 finished
# Episode 1454 finished
# Episode 1455 finished
# Episode 1456 finished
# Episode 1457 finished
# Episode 1458 finished
# Episode 1459 finished
# Episode 1460 finished
# Episode 1461 finished
# Episode 1462 finished
# Episode 1463 finished
# Episode 1464 finished
# Episode 1465 finished
# Episode 1466 finished
# Episode 1467 finished
# Episode 1468 finished
# Episode 1469 finished
# Episode 1470 finished
# Episode 1471 finished
# Episode 1472 finished
# Episode 1473 finished
# Episode 1474 finished
# Episode 1475 finished
# Episode 1476 finished
# Episode 1477 finished
# Episode 1478 finished
# Episode 1479 finished
# Episode 1480 finished
# Episode 1481 finished
# Episode 1482 finished
# Episode 1483 finished
# Episode 1484 finished
# Episode 1485 finished
# Episode 1486 finished
# Episode 1487 finished
# Episode 1488 finished
# Episode 1489 finished
# Episode 1490 finished
# Episode 1491 finished
# Episode 1492 finished
# Episode 1493 finished
# Episode 1494 finished
# Episode 1495 finished
# Episode 1496 finished
# Episode 1497 finished
# Episode 1498 finished
# Episode 1499 finished
# Episode 1500 finished
# Model saved to origins_models/q_network-1500.pth
# Episode 1501 finished
# Episode 1502 finished
# Episode 1503 finished
# Episode 1504 finished
# Episode 1505 finished
# Episode 1506 finished
# Episode 1507 finished
# Episode 1508 finished
# Episode 1509 finished
# Episode 1510 finished
# Episode 1511 finished
# Episode 1512 finished
# Episode 1513 finished
# Episode 1514 finished
# Episode 1515 finished
# Episode 1516 finished
# Episode 1517 finished
# Episode 1518 finished
# Episode 1519 finished
# Episode 1520 finished
# Episode 1521 finished
# Episode 1522 finished
# Episode 1523 finished
# Episode 1524 finished
# Episode 1525 finished
# Episode 1526 finished
# Episode 1527 finished
# Episode 1528 finished
# Episode 1529 finished
# Episode 1530 finished
# Episode 1531 finished
# Episode 1532 finished
# Episode 1533 finished
# Episode 1534 finished
# Episode 1535 finished
# Episode 1536 finished
# Episode 1537 finished
# Episode 1538 finished
# Episode 1539 finished
# Episode 1540 finished
# Episode 1541 finished
# Episode 1542 finished
# Episode 1543 finished
# Episode 1544 finished
# Episode 1545 finished
# Episode 1546 finished
# Episode 1547 finished
# Episode 1548 finished
# Episode 1549 finished
# Episode 1550 finished
# Episode 1551 finished
# Episode 1552 finished
# Episode 1553 finished
# Episode 1554 finished
# Episode 1555 finished
# Episode 1556 finished
# Episode 1557 finished
# Episode 1558 finished
# Episode 1559 finished
# Episode 1560 finished
# Episode 1561 finished
# Episode 1562 finished
# Episode 1563 finished
# Episode 1564 finished
# Episode 1565 finished
# Episode 1566 finished
# Episode 1567 finished
# Episode 1568 finished
# Episode 1569 finished
# Episode 1570 finished
# Episode 1571 finished
# Episode 1572 finished
# Episode 1573 finished
# Episode 1574 finished
# Episode 1575 finished
# Episode 1576 finished
# Episode 1577 finished
# Episode 1578 finished
# Episode 1579 finished
# Episode 1580 finished
# Episode 1581 finished
# Episode 1582 finished
# Episode 1583 finished
# Episode 1584 finished
# Episode 1585 finished
# Episode 1586 finished
# Episode 1587 finished
# Episode 1588 finished
# Episode 1589 finished
# Episode 1590 finished
# Episode 1591 finished
# Episode 1592 finished
# Episode 1593 finished
# Episode 1594 finished
# Episode 1595 finished
# Episode 1596 finished
# Episode 1597 finished
# Episode 1598 finished
# Episode 1599 finished
# Episode 1600 finished
# Model saved to origins_models/q_network-1600.pth
# Episode 1601 finished
# Episode 1602 finished
# Episode 1603 finished
# Episode 1604 finished
# Episode 1605 finished
# Episode 1606 finished
# Episode 1607 finished
# Episode 1608 finished
# Episode 1609 finished
# Episode 1610 finished
# Episode 1611 finished
# Episode 1612 finished
# Episode 1613 finished
# Episode 1614 finished
# Episode 1615 finished
# Episode 1616 finished
# Episode 1617 finished
# Episode 1618 finished
# Episode 1619 finished
# Episode 1620 finished
# Episode 1621 finished
# Episode 1622 finished
# Episode 1623 finished
# Episode 1624 finished
# Episode 1625 finished
# Episode 1626 finished
# Episode 1627 finished
# Episode 1628 finished
# Episode 1629 finished
# Episode 1630 finished
# Episode 1631 finished
# Episode 1632 finished
# Episode 1633 finished
# Episode 1634 finished
# Episode 1635 finished
# Episode 1636 finished
# Episode 1637 finished
# Episode 1638 finished
# Episode 1639 finished
# Episode 1640 finished
# Episode 1641 finished
# Episode 1642 finished
# Episode 1643 finished
# Episode 1644 finished
# Episode 1645 finished
# Episode 1646 finished
# Episode 1647 finished
# Episode 1648 finished
# Episode 1649 finished
# Episode 1650 finished
# Episode 1651 finished
# Episode 1652 finished
# Episode 1653 finished
# Episode 1654 finished
# Episode 1655 finished
# Episode 1656 finished
# Episode 1657 finished
# Episode 1658 finished
# Episode 1659 finished
# Episode 1660 finished
# Episode 1661 finished
# Episode 1662 finished
# Episode 1663 finished
# Episode 1664 finished
# Episode 1665 finished
# Episode 1666 finished
# Episode 1667 finished
# Episode 1668 finished
# Episode 1669 finished
# Episode 1670 finished
# Episode 1671 finished
# Episode 1672 finished
# Episode 1673 finished
# Episode 1674 finished
# Episode 1675 finished
# Episode 1676 finished
# Episode 1677 finished
# Episode 1678 finished
# Episode 1679 finished
# Episode 1680 finished
# Episode 1681 finished
# Episode 1682 finished
# Episode 1683 finished
# Episode 1684 finished
# Episode 1685 finished
# Episode 1686 finished
# Episode 1687 finished
# Episode 1688 finished
# Episode 1689 finished
# Episode 1690 finished
# Episode 1691 finished
# Episode 1692 finished
# Episode 1693 finished
# Episode 1694 finished
# Episode 1695 finished
# Episode 1696 finished
# Episode 1697 finished
# Episode 1698 finished
# Episode 1699 finished
# Episode 1700 finished
# Model saved to origins_models/q_network-1700.pth
# Episode 1701 finished
# Episode 1702 finished
# Episode 1703 finished
# Episode 1704 finished
# Episode 1705 finished
# Episode 1706 finished
# Episode 1707 finished
# Episode 1708 finished
# Episode 1709 finished
# Episode 1710 finished
# Episode 1711 finished
# Episode 1712 finished
# Episode 1713 finished
# Episode 1714 finished
# Episode 1715 finished
# Episode 1716 finished
# Episode 1717 finished
# Episode 1718 finished
# Episode 1719 finished
# Episode 1720 finished
# Episode 1721 finished
# Episode 1722 finished
# Episode 1723 finished
# Episode 1724 finished
# Episode 1725 finished
# Episode 1726 finished
# Episode 1727 finished
# Episode 1728 finished
# Episode 1729 finished
# Episode 1730 finished
# Episode 1731 finished
# Episode 1732 finished
# Episode 1733 finished
# Episode 1734 finished
# Episode 1735 finished
# Episode 1736 finished
# Episode 1737 finished
# Episode 1738 finished
# Episode 1739 finished
# Episode 1740 finished
# Episode 1741 finished
# Episode 1742 finished
# Episode 1743 finished
# Episode 1744 finished
# Episode 1745 finished
# Episode 1746 finished
# Episode 1747 finished
# Episode 1748 finished
# Episode 1749 finished
# Episode 1750 finished
# Episode 1751 finished
# Episode 1752 finished
# Episode 1753 finished
# Episode 1754 finished
# Episode 1755 finished
# Episode 1756 finished
# Episode 1757 finished
# Episode 1758 finished
# Episode 1759 finished
# Episode 1760 finished
# Episode 1761 finished
# Episode 1762 finished
# Episode 1763 finished
# Episode 1764 finished
# Episode 1765 finished
# Episode 1766 finished
# Episode 1767 finished
# Episode 1768 finished
# Episode 1769 finished
# Episode 1770 finished
# Episode 1771 finished
# Episode 1772 finished
# Episode 1773 finished
# Episode 1774 finished
# Episode 1775 finished
# Episode 1776 finished
# Episode 1777 finished
# Episode 1778 finished
# Episode 1779 finished
# Episode 1780 finished
# Episode 1781 finished
# Episode 1782 finished
# Episode 1783 finished
# Episode 1784 finished
# Episode 1785 finished
# Episode 1786 finished
# Episode 1787 finished
# Episode 1788 finished
# Episode 1789 finished
# Episode 1790 finished
# Episode 1791 finished
# Episode 1792 finished
# Episode 1793 finished
# Episode 1794 finished
# Episode 1795 finished
# Episode 1796 finished
# Episode 1797 finished
# Episode 1798 finished
# Episode 1799 finished
# Episode 1800 finished
# Model saved to origins_models/q_network-1800.pth
# Episode 1801 finished
# Episode 1802 finished
# Episode 1803 finished
# Episode 1804 finished
# Episode 1805 finished
# Episode 1806 finished
# Episode 1807 finished
# Episode 1808 finished
# Episode 1809 finished
# Episode 1810 finished
# Episode 1811 finished
# Episode 1812 finished
# Episode 1813 finished
# Episode 1814 finished
# Episode 1815 finished
# Episode 1816 finished
# Episode 1817 finished
# Episode 1818 finished
# Episode 1819 finished
# Episode 1820 finished
# Episode 1821 finished
# Episode 1822 finished
# Episode 1823 finished
# Episode 1824 finished
# Episode 1825 finished
# Episode 1826 finished
# Episode 1827 finished
# Episode 1828 finished
# Episode 1829 finished
# Episode 1830 finished
# Episode 1831 finished
# Episode 1832 finished
# Episode 1833 finished
# Episode 1834 finished
# Episode 1835 finished
# Episode 1836 finished
# Episode 1837 finished
# Episode 1838 finished
# Episode 1839 finished
# Episode 1840 finished
# Episode 1841 finished
# Episode 1842 finished
# Episode 1843 finished
# Episode 1844 finished
# Episode 1845 finished
# Episode 1846 finished
# Episode 1847 finished
# Episode 1848 finished
# Episode 1849 finished
# Episode 1850 finished
# Episode 1851 finished
# Episode 1852 finished
# Episode 1853 finished
# Episode 1854 finished
# Episode 1855 finished
# Episode 1856 finished
# Episode 1857 finished
# Episode 1858 finished
# Episode 1859 finished
# Episode 1860 finished
# Episode 1861 finished
# Episode 1862 finished
# Episode 1863 finished
# Episode 1864 finished
# Episode 1865 finished
# Episode 1866 finished
# Episode 1867 finished
# Episode 1868 finished
# Episode 1869 finished
# Episode 1870 finished
# Episode 1871 finished
# Episode 1872 finished
# Episode 1873 finished
# Episode 1874 finished
# Episode 1875 finished
# Episode 1876 finished
# Episode 1877 finished
# Episode 1878 finished
# Episode 1879 finished
# Episode 1880 finished
# Episode 1881 finished
# Episode 1882 finished
# Episode 1883 finished
# Episode 1884 finished
# Episode 1885 finished
# Episode 1886 finished
# Episode 1887 finished
# Episode 1888 finished
# Episode 1889 finished
# Episode 1890 finished
# Episode 1891 finished
# Episode 1892 finished
# Episode 1893 finished
# Episode 1894 finished
# Episode 1895 finished
# Episode 1896 finished
# Episode 1897 finished
# Episode 1898 finished
# Episode 1899 finished
# Episode 1900 finished
# Model saved to origins_models/q_network-1900.pth
# Episode 1901 finished
# Episode 1902 finished
# Episode 1903 finished
# Episode 1904 finished
# Episode 1905 finished
# Episode 1906 finished
# Episode 1907 finished
# Episode 1908 finished
# Episode 1909 finished
# Episode 1910 finished
# Episode 1911 finished
# Episode 1912 finished
# Episode 1913 finished
# Episode 1914 finished
# Episode 1915 finished
# Episode 1916 finished
# Episode 1917 finished
# Episode 1918 finished
# Episode 1919 finished
# Episode 1920 finished
# Episode 1921 finished
# Episode 1922 finished
# Episode 1923 finished
# Episode 1924 finished
# Episode 1925 finished
# Episode 1926 finished
# Episode 1927 finished
# Episode 1928 finished
# Episode 1929 finished
# Episode 1930 finished
# Episode 1931 finished
# Episode 1932 finished
# Episode 1933 finished
# Episode 1934 finished
# Episode 1935 finished
# Episode 1936 finished
# Episode 1937 finished
# Episode 1938 finished
# Episode 1939 finished
# Episode 1940 finished
# Episode 1941 finished
# Episode 1942 finished
# Episode 1943 finished
# Episode 1944 finished
# Episode 1945 finished
# Episode 1946 finished
# Episode 1947 finished
# Episode 1948 finished
# Episode 1949 finished
# Episode 1950 finished
# Episode 1951 finished
# Episode 1952 finished
# Episode 1953 finished
# Episode 1954 finished
# Episode 1955 finished
# Episode 1956 finished
# Episode 1957 finished
# Episode 1958 finished
# Episode 1959 finished
# Episode 1960 finished
# Episode 1961 finished
# Episode 1962 finished
# Episode 1963 finished
# Episode 1964 finished
# Episode 1965 finished
# Episode 1966 finished
# Episode 1967 finished
# Episode 1968 finished
# Episode 1969 finished
# Episode 1970 finished
# Episode 1971 finished
# Episode 1972 finished
# Episode 1973 finished
# Episode 1974 finished
# Episode 1975 finished
# Episode 1976 finished
# Episode 1977 finished
# Episode 1978 finished
# Episode 1979 finished
# Episode 1980 finished
# Episode 1981 finished
# Episode 1982 finished
# Episode 1983 finished
# Episode 1984 finished
# Episode 1985 finished
# Episode 1986 finished
# Episode 1987 finished
# Episode 1988 finished
# Episode 1989 finished
# Episode 1990 finished
# Episode 1991 finished
# Episode 1992 finished
# Episode 1993 finished
# Episode 1994 finished
# Episode 1995 finished
# Episode 1996 finished
# Episode 1997 finished
# Episode 1998 finished
# Episode 1999 finished
# Episode 2000 finished
# Model saved to origins_models/q_network-2000.pth
# Episode 2001 finished
# Episode 2002 finished
# Episode 2003 finished
# Episode 2004 finished
# Episode 2005 finished
# Episode 2006 finished
# Episode 2007 finished
# Episode 2008 finished
# Episode 2009 finished
# Episode 2010 finished
# Episode 2011 finished
# Episode 2012 finished
# Episode 2013 finished
# Episode 2014 finished
# Episode 2015 finished
# Episode 2016 finished
# Episode 2017 finished
# Episode 2018 finished
# Episode 2019 finished
# Episode 2020 finished
# Episode 2021 finished
# Episode 2022 finished
# Episode 2023 finished
# Episode 2024 finished
# Episode 2025 finished
# Episode 2026 finished
# Episode 2027 finished
# Episode 2028 finished
# Episode 2029 finished
# Episode 2030 finished
# Episode 2031 finished
# Episode 2032 finished
# Episode 2033 finished
# Episode 2034 finished
# Episode 2035 finished
# Episode 2036 finished
# Episode 2037 finished
# Episode 2038 finished
# Episode 2039 finished
# Episode 2040 finished
# Episode 2041 finished
# Episode 2042 finished
# Episode 2043 finished
# Episode 2044 finished
# Episode 2045 finished
# Episode 2046 finished
# Episode 2047 finished
# Episode 2048 finished
# Episode 2049 finished
# Episode 2050 finished
# Episode 2051 finished
# Episode 2052 finished
# Episode 2053 finished
# Episode 2054 finished
# Episode 2055 finished
# Episode 2056 finished
# Episode 2057 finished
# Episode 2058 finished
# Episode 2059 finished
# Episode 2060 finished
# Episode 2061 finished
# Episode 2062 finished
# Episode 2063 finished
# Episode 2064 finished
# Episode 2065 finished
# Episode 2066 finished
# Episode 2067 finished
# Episode 2068 finished
# Episode 2069 finished
# Episode 2070 finished
# Episode 2071 finished
# Episode 2072 finished
# Episode 2073 finished
# Episode 2074 finished
# Episode 2075 finished
# Episode 2076 finished
# Episode 2077 finished
# Episode 2078 finished
# Episode 2079 finished
# Episode 2080 finished
# Episode 2081 finished
# Episode 2082 finished
# Episode 2083 finished
# Episode 2084 finished
# Episode 2085 finished
# Episode 2086 finished
# Episode 2087 finished
# Episode 2088 finished
# Episode 2089 finished
# Episode 2090 finished
# Episode 2091 finished
# Episode 2092 finished
# Episode 2093 finished
# Episode 2094 finished
# Episode 2095 finished
# Episode 2096 finished
# Episode 2097 finished
# Episode 2098 finished
# Episode 2099 finished
# Episode 2100 finished
# Model saved to origins_models/q_network-2100.pth
# Episode 2101 finished
# Episode 2102 finished
# Episode 2103 finished
# Episode 2104 finished
# Episode 2105 finished
# Episode 2106 finished
# Episode 2107 finished
# Episode 2108 finished
# Episode 2109 finished
# Episode 2110 finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 176
#     174 action = agent.choose_action(state)
#     175 next_state, reward, done, _ = env.step(action)
# --> 176 agent.learn(state, action, reward, next_state)
#     177 state = next_state
#     178 if done:
#
# Cell In[7], line 132, in DeepQLearningAgent.learn(self, state, action, reward, next_state)
#     130 self.optimizer.zero_grad()
#     131 loss.backward()
# --> 132 self.optimizer.step()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:168, in Adam.step(self, closure)
#     157     beta1, beta2 = group['betas']
#     159     has_complex = self._init_group(
#     160         group,
#     161         params_with_grad,
#    (...)
#     165         max_exp_avg_sqs,
#     166         state_steps)
# --> 168     adam(
#     169         params_with_grad,
#     170         grads,
#     171         exp_avgs,
#     172         exp_avg_sqs,
#     173         max_exp_avg_sqs,
#     174         state_steps,
#     175         amsgrad=group['amsgrad'],
#     176         has_complex=has_complex,
#     177         beta1=beta1,
#     178         beta2=beta2,
#     179         lr=group['lr'],
#     180         weight_decay=group['weight_decay'],
#     181         eps=group['eps'],
#     182         maximize=group['maximize'],
#     183         foreach=group['foreach'],
#     184         capturable=group['capturable'],
#     185         differentiable=group['differentiable'],
#     186         fused=group['fused'],
#     187         grad_scale=getattr(self, "grad_scale", None),
#     188         found_inf=getattr(self, "found_inf", None),
#     189     )
#     191 return loss
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:318, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     315 else:
#     316     func = _single_tensor_adam
# --> 318 func(params,
#     319      grads,
#     320      exp_avgs,
#     321      exp_avg_sqs,
#     322      max_exp_avg_sqs,
#     323      state_steps,
#     324      amsgrad=amsgrad,
#     325      has_complex=has_complex,
#     326      beta1=beta1,
#     327      beta2=beta2,
#     328      lr=lr,
#     329      weight_decay=weight_decay,
#     330      eps=eps,
#     331      maximize=maximize,
#     332      capturable=capturable,
#     333      differentiable=differentiable,
#     334      grad_scale=grad_scale,
#     335      found_inf=found_inf)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:384, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     381 if weight_decay != 0:
#     382     grad = grad.add(param, alpha=weight_decay)
# --> 384 if torch.is_complex(param):
#     385     grad = torch.view_as_real(grad)
#     386     exp_avg = torch.view_as_real(exp_avg)
#
# KeyboardInterrupt:
